# %%
import sys
sys.path.append('../src/')
import tfsummary as tfs
import tfparameter as tfp
import main

tfs.TREND_FILE_DIR = '../data/quadratic_0.1/'
run_parameter = tfp.TFRunParameter(learning_rate=0.01,
                                   training_iters=500,
                                   batch_size=5,
                                   display_step=1)
nn_parameter = tfp.TFNNParameter(n_input=1,
                                 n_steps=30,
                                 n_hidden=32,
                                 n_classes=5)
runner = main.TFNeuralNet(run_parameter, nn_parameter)
runner.train()
# Out:
# ('TFMinibatch init num_of_class:', 5)
# list_class_limit
# [-2.5, -1.5, 0.5, 1.5, 2.5]
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-1-9358f6c6887b> in <module>()
#      15                                  n_classes=5)
#      16 runner = main.TFNeuralNet(run_parameter, nn_parameter)
# ---> 17 runner.train()
#
# /home/yokonami/git/tfstock/src/main.pyc in train(self)
#     133                 #batch_x = batch_x.reshape((batch_size, n_steps, n_input))
#     134                 # Run optimization op (backprop)
# --> 135                 sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
#     136                 if step % display_step == 0:
#     137                     # Calculate batch accuracy
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
# ...
