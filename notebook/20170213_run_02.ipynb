# %%
import sys
sys.path.append('../src/')
import tfsummary as tfs
import tfparameter as tfp
import main

tfs.TREND_FILE_DIR = '../data/quadratic_0.5/'
run_parameter = tfp.TFRunParameter(learning_rate=0.1,
                                   training_iters=300,
                                   batch_size=5,
                                   display_step=1)
nn_parameter = tfp.TFNNParameter(n_input=1,
                                 n_steps=30,
                                 n_hidden=16,
                                 n_classes=5)
runner = main.TFNeuralNet(run_parameter, nn_parameter)
runner.train()
# Out:
# ('TFMinibatch init num_of_class:', 5)
# list_class_limit
# [-2.5, -1.5, 0.5, 1.5, 2.5]
# Optimization Finished!
# Testing Accuracy: 0.3
